# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib nbagg

# %%
a = np.random.rand()
b = 3
c = a + b
print ("Estos son los datos:")
print ("Dato a = " + str(a))
print ("Dato b = " + str(b))
print ("Dato c = a+b = " + str(c))
vecX = np.random.rand(1,100)[0]
vecY = np.random.rand(1,100)[0]
plt.figure()
plt.figure(211)
plt.plot (vecX)
plt.title("vec X")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
plt.figure()
plt.figure(212)
plt.plot (vecY)
plt.title("vec Y")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.grid(True)
# Out:
# Estos son los datos:
# Dato a = 0.04833293592294097
# Dato b = 3
# Dato c = a+b = 3.048332935922941
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
# %matplotlib?

# %%
vecY.shape
# Out:
# (100,)
